# %%
from IPython.display import clear_output

clear_output()
game_on='True'

marks=[' ','1','2','3','4','5','6','7','8','9']
marksi=[' ','1','2','3','4','5','6','7','8','9']

def display_board(board):
    print('   |   |')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |')
    
def choose_sign():
    SignA = 'wrong'
    while SignA not in ['X','O']:
        
        # we shouldn't convert here, otherwise we get an error on a wrong input
        SignA = input("Player 1 : Choose your Mark, only options are X or O :")

        
        if SignA not in ['X','O']:
        
            # THIS CLEARS THE CURRENT OUTPUT BELOW THE CELL
            clear_output()
            
            print("Sorry, I didn't understand. Please make sure to choose X or O.")
            
    
    # Optionally you can clear everything after running the function
    # clear_output()
    
    
    if SignA == 'X':
        SignB = 'O'
    else:
        SignB = 'X'
    clear_output()
    return (SignA, SignB)

def game_not_over(board):
    if board[7]==board[8] and board[8]==board[9]:
        return False
    if board[4]==board[5] and board[5]==board[6]:
        return False
    if board[1]==board[2] and board[2]==board[3]:
        return False
    if board[1]==board[4] and board[4]==board[7]:
        return False
    if board[2]==board[5] and board[5]==board[8]:
        return False
    if board[3]==board[6] and board[6]==board[9]:
        return False
    if board[7]==board[5] and board[5]==board[3]:
        return False
    if board[1]==board[5] and board[5]==board[9]:
        return False
    else:
        return True
    
def choose_position_A(num):
    position_A = input("Player 1 : Choose your position :")
    marks[int(position_A)]=Signs[0]
    clear_output()
    display_board(marks)
    Result=game_not_over(marks)
    return Result

def choose_position_B(num):
    position_B = input("Player 2 : Choose your position :")
    marks[int(position_B)]=Signs[1]
    clear_output()
    display_board(marks)
    Result=game_not_over(marks)
    return Result
    
def game_continue():
    
    # This original choice value can be anything that isn't a Y or N
    game_on = 'wrong'
    
    # While the choice is not a digit, keep asking for input.
    while game_on not in ['Y','N']:
        
        # we shouldn't convert here, otherwise we get an error on a wrong input
        game_on = input("Would you like to keep playing? Y or N ")

        
        if game_on not in ['Y','N']:
            # THIS CLEARS THE CURRENT OUTPUT BELOW THE CELL
            clear_output()
            
            print("Sorry, I didn't understand. Please make sure to choose Y or N.")
            
    
    # Optionally you can clear everything after running the function
    # clear_output()
    
    
    
    if game_on == 'Y' or game_on == 'y':
        clear_output()
        return True
    else:
        clear_output()
        print("OK. Goodbye")
        return False
    
def check_for_tie(num,Result):
    if num==9 and Result==True:
        Result= False
    else:
        Result=Result
        

print("Hello Tic Tac Toe Gamers")

while(game_on):
    marks=[' ','1','2','3','4','5','6','7','8','9']
    Result = True
    Winner = 'Player B'
    num=0
    Signs = choose_sign()
    print("Player 1 symbol : {}".format(Signs[0]))
    print("Player 2 symbol : {}".format(Signs[1]))
    print("Lets Begin\n")
    display_board(marks)
    
    while(Result and num!=9):
        Result = choose_position_A(num)
        num=num+1
        #Result = check_for_tie(num,Result)
        if Result == True and num<9:
            Result = choose_position_B(num)
            num=num+1
            #Result = check_for_tie(num,Result)
        else:
            Winner = 'Player A'
            break
    
    if num<=9 and Result == False:
        print("Game Over and the winner is {}".format(Winner))
    else:
        print("Its a tie, you suck")
    game_on = game_continue()
# Out:
# Player 1 symbol : X
# Player 2 symbol : O
# Lets Begin
#
#    |   |
#  7 | 8 | 9
#    |   |
# -----------
#    |   |
#  4 | 5 | 6
#    |   |
# -----------
#    |   |
#  1 | 2 | 3
#    |   |

# %% [markdown]
# 1# num

# %%
num
# Out:
# 1
